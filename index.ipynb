# %%
#| hide
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # ruler_calc
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install ruler_calc
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %% [markdown]
# # １行で使う

# %%
from ruler_calc.api import Ruler as r
print(r.calc("data/simple.jpeg"))
# Out:
# {'path': 'tmp/result.jpg', 'width': 222, 'height': 168, 'pixelPerMM': 16}

# %% [markdown]
# # その他の例

# %% [markdown]
# デモ用の関数

# %%
import matplotlib.pyplot as plt
from pprint import pprint
import matplotlib.image as mpimg

def show(result):
    # pprint(result)
    pixelPerMM = result['pixelPerMM']
    w = result['width']
    h = result['height']
    print("1 mm = {} pixels".format(pixelPerMM))
    print("入力画像のサイズ: {} mm x {} mm".format(round(w / pixelPerMM), round(h / pixelPerMM)))

# %% [markdown]
# ## 例1

# %%
path = "data/612110.jpeg"
task_id = 1
plt.imshow(mpimg.imread(path),cmap="gray")

# %%
result = r.calc(path, task_id)
show(result)
# Out:
# 1 mm = 3 pixels
# 入力画像のサイズ: 187 mm x 140 mm

# %%
plt.imshow(mpimg.imread(result["path"]),cmap="gray")

# %% [markdown]
# ## 例2

# %%
path = "data/IiReU.jpeg"
plt.imshow(mpimg.imread(path),cmap="gray")
task_id = 2

# %%
result = r.calc(path, task_id)
show(result)
# Out:
# 1 mm = 8 pixels
# 入力画像のサイズ: 75 mm x 32 mm

# %%
plt.imshow(mpimg.imread(result["path"]),cmap="gray")

# %% [markdown]
# ## 例3

# %%
path = "data/IiReU_2.jpeg"
plt.imshow(mpimg.imread(path),cmap="gray")
task_id = 4

# %%
result = r.calc(path, task_id)
show(result)
# Out:
# 1 mm = 8 pixels
# 入力画像のサイズ: 75 mm x 32 mm

# %%
plt.imshow(mpimg.imread(result["path"]),cmap="gray")

# %% [markdown]
# ## 例4

# %%
path = "data/0e067eb07d7b435ce8b1074513efd41a.jpeg"
task_id = 3
plt.imshow(mpimg.imread(path),cmap="gray")

# %%
result = r.calc(path, task_id)
show(result)
# Out:
# 1 mm = 16 pixels
# 入力画像のサイズ: 191 mm x 15 mm

# %%
plt.imshow(mpimg.imread(result["path"]),cmap="gray")

# %% [markdown]
# ## 例5

# %%
path = "data/ndl.png"
task_id = 5
plt.imshow(mpimg.imread(path),cmap="gray")

# %%
result = r.calc(path, task_id)
show(result)
# Out:
# 1 mm = 15 pixels
# 入力画像のサイズ: 98 mm x 16 mm

# %%
plt.imshow(mpimg.imread(result["path"]),cmap="gray")

# %% [markdown]
# ## 例6

# %%
path = "data/hi2.png"
task_id = 6
plt.imshow(mpimg.imread(path),cmap="gray")

# %%
result = r.calc(path, task_id)
show(result)
# Out:
# 1 mm = 14 pixels
# 入力画像のサイズ: 106 mm x 11 mm

# %%
plt.imshow(mpimg.imread(result["path"]),cmap="gray")
